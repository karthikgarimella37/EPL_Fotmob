# %%
# https://www.fotmob.com/api/matchDetails?matchId=4506348
import requests

# %%
headers = {
    "X-Mas": "eyJib2R5Ijp7InVybCI6Ii9hcGkvbWF0Y2hEZXRhaWxzP21hdGNoSWQ9NDUwNjM0OCIsImNvZGUiOjE3NDMyMjI4MzA2OTAsImZvbyI6InByb2R1Y3Rpb246NDJlZWVlNmVlM2UzNmNhNDgyNmExMzkyYWIzMWE4ODk1YzNjODc0Yi11bmRlZmluZWQifSwic2lnbmF0dXJlIjoiMTZDNTc5QzZBMEE2MDY5QUMzMjAyMUM0RkMzRUE1QjcifQ=="
}

url = "https://www.fotmob.com/api/matchDetails?matchId=4506348"
response  = requests.get(url, headers=headers)
site = response.json()

# %%
url = "https://www.fotmob.com/api/fixtures?id=47&season=2014%2F2015"
response  = requests.get(url, headers=headers)
site = response.json()

# %%
len(site)
# Out:
# 380

# %%
site[0]['id']
# Out:
# '1723986'

# %%
all_seasons = []
for i in range(2010, 2024):
    url = f"https://www.fotmob.com/api/fixtures?id=47&season={i}%2F{i+1}"
    response  = requests.get(url, headers=headers)
    site = response.json()

    for sit in site:
        # print(sit['id'])
        all_seasons.append(sit['id'])

# %%
len(all_seasons)
# Out:
# 5321

# %%
site[0]['data']
# Out:
# {'ccode': 'ENG',
#  'leagueId': 47,
#  'pageUrl': '/leagues/47/overview/premier-league',
#  'leagueName': 'Premier League',
#  'legend': [{'title': 'Champions League',
#    'tKey': 'championsleague',
#    'color': '#2AD572',
#    'indices': [0, 1, 2, 3]},
#   {'title': 'Europa League',
#    'tKey': 'europaleague',
#    'color': '#0046A7',
#    'indices': [4]},
#   {'title': 'Relegation',
#    'tKey': 'relegation',
#    'color': '#FF4646',
#    'indices': [17, 18, 19]}],
#  'ongoing': [],
#  'table': {'all': [{'name': 'Liverpool',
#     'shortName': 'Liverpool',
#     'id': 8650,
#     'pageUrl': '/teams/8650/overview/liverpool',
#     'deduction': None,
#     'ongoing': None,
#     'played': 29,
#     'wins': 21,
#     'draws': 7,
#     'losses': 1,
#     'scoresStr': '69-27',
#     'goalConDiff': 42,
#     'pts': 70,
#     'idx': 1,
#     'qualColor': '#2AD572'},
#    {'name': 'Arsenal',
#     'shortName': 'Arsenal',
#     'id': 9825,
# ...

# %%
site['content'].keys()
# Out:
# dict_keys(['matchFacts', 'liveticker', 'superlive', 'buzz', 'stats', 'playerStats', 'shotmap', 'lineup', 'playoff', 'table', 'h2h', 'momentum', 'highlightStories'])

# %%
site['content']['playerStats'].keys()
# Out:
# dict_keys(['157723', '176186', '208494', '246575', '258269', '282775', '318615', '422685', '434325', '534670', '562727', '574645', '582499', '611491', '623621', '654096', '751550', '769895', '775539', '776151', '795179', '942381', '950830', '955406', '1021586', '1021834', '1105912', '1199272', '1203665', '1254234', '1315314', '1358581', '1367699', '1406436', '1421810', '1422743', '1430832', '1557220', '1559639', '1575707'])
